# %% [markdown]
# ### ตรวจสภาพแวดล้อม

# %%
import sys ,platform
print(sys.executable)
print(platform.system)
# Out:
# /opt/conda/bin/python
# <function system at 0x78539dbde200>

# %% [markdown]
# ### เลือกไซต์

# %%
import os
os.environ["UWIN_SITE"] = "013054"

from uwinControl import config
SITE = config.get_site()
print(SITE["station_code"])
# Out:
# 013054

# %% [markdown]
# ### โหลดข้อมูลจาก ERA5

# %%
from uwinControl import reference

# โหลดเป็นช่วงเดือน กัน limit
for month in range(1, 13):
    reference.download_era5(2024, month)

# %%
from uwinControl import reference

reference.download_era5_range()
# Out:
# ข้าม 2006-01 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2006-02 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2006-03 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2006-04 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2006-05 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2006-06 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2006-07 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2006-08 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2006-09 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2006-10 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2006-11 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2006-12 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2007-01 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2007-02 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2007-03 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2007-04 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2007-05 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2007-06 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2007-07 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2007-08 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2007-09 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2007-10 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2007-11 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2007-12 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2008-01 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2008-02 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2008-03 (มีไฟล์แล้ว 0.2 MB)
# ข้าม 2008-04 (มีไฟล์แล้ว 0.2 MB)
# ...

# %%
# โหลดเป็นช่วงเดือน กัน limit
for month in range(1, 13):
    reference.download_era5(2006, month)
